# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install kaggle --upgrade
# Out:
# ...
#      |████████████████████████████████| 61kB 5.0MB/s
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.6-cp36-none-any.whl size=72859 sha256=d559cbf0bb9111c24b57615fa86527590ab8070d4b8967b67c64d56e2ed06235
#   Stored in directory: /root/.cache/pip/wheels/57/4e/e8/bb28d035162fb8f17f8ca5d42c3230e284c6aa565b42b72674
# Successfully built kaggle
# ...
#   Found existing installation: kaggle 1.5.5
#     Uninstalling kaggle-1.5.5:
#       Successfully uninstalled kaggle-1.5.5
# ...

# %%
# !git clone https://github.com/zhixuhao/unet.git
# Out:
# fatal: destination path 'unet' already exists and is not an empty directory.

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !mv unet DIVE-INTO-CODE

# %%
# !mv DIVE-INTO-CODE unet

# %%
# %cd /content/drive/My Drive/Colab Notebooks/dive/Sprint19
# Out:
# /content/drive/My Drive/Colab Notebooks/dive/Sprint19

# %%
# !ls
# Out:
# DIVE-INTO-CODE

# %%
# !mv unet DIVE-INTO-CODE
# Out:
# mv: cannot stat 'unet': No such file or directory

# %%
# !cd content
# Out:
# /bin/bash: line 0: cd: content: No such file or directory

# %%
# %cd content
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data  unet

# %%
# %mv unet
# Out:
# mv: target 'Notebooks/DIVE-INTO-CODE/Sprint19' is not a directory

# %%
# !mv /content/unet "/content/drive/My Drive/Colab Notebooks/DIVE-INTO-CODE/Sprint19"

# %%
# !pip install kaggle

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/dive"
# Out:
# /content/drive/My Drive/Colab Notebooks/dive

# %%
mkdir .kaggle
# Out:
# mkdir: cannot create directory ‘.kaggle’: File exists

# %%
# !ls -a
# Out:
# .kaggle  Sprint19  Sprint20

# %%
import json

token = {'username':'yukitakamori','key':'9218819f95245f1858742a0567990f09'}
with open('/content/drive/My Drive/Colab Notebooks/dive/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !chmod 600 '/content/drive/My Drive/Colab Notebooks/dive/.kaggle/kaggle.json'

# %%
# !cp '/content/drive/My Drive/Colab Notebooks/dive/.kaggle/kaggle.json' /root/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c tgs-salt-identification-challenge
# Out:
# ...
#  96% 193M/200M [00:04<00:00, 62.3MB/s]
# 100% 200M/200M [00:04<00:00, 47.0MB/s]

# %%
# !pwd
# Out:
# /content

# %%
# !unzip /content/tgs-salt-identification-challenge.zip  -d Salt
# Out:
# Archive:  /content/tgs-salt-identification-challenge.zip
#   inflating: Salt/depths.csv
#   inflating: Salt/train.zip
#   inflating: Salt/sample_submission.csv
#   inflating: Salt/test.zip
#   inflating: Salt/train.csv

# %%
# !mv /content/Salt /content/drive/My Drive/Colab Notebooks/dive/Sprint19
# Out:
# mv: target 'Notebooks/dive/Sprint19' is not a directory

# %%
# %cd /content/drive/My Drive/Colab Notebooks/dive/Sprint19
# Out:
# /content/drive/My Drive/Colab Notebooks/dive/Sprint19

# %%
# !mv /content/Salt '/content/drive/My Drive/Colab Notebooks/dive/Sprint19'

# %%
# !unzip '/content/drive/My Drive/Colab Notebooks/dive/Sprint19/Salt/train.zip'

# %%
# %cd /content/drive/My Drive/Colab Notebooks/dive/Sprint19/Salt
# Out:
# /content/drive/My Drive/Colab Notebooks/dive/Sprint19/Salt

# %%
# !mkdir traindata

# %%
# !mkdir testdata

# %%
# !mv '/content/drive/My Drive/Colab Notebooks/dive/Sprint19/images' '/content/drive/My Drive/Colab Notebooks/dive/Sprint19/Salt/traindata'
# Out:
# mv: cannot stat '/content/drive/My Drive/Colab Notebooks/dive/Sprint19/images': No such file or directory

# %%
# !mv '/content/drive/My Drive/Colab Notebooks/dive/Sprint19/masks' '/content/drive/My Drive/Colab Notebooks/dive/Sprint19/Salt/traindata'

# %%
# !mv '/content/drive/My Drive/Colab Notebooks/dive/Sprint19/Salt/testdata/images' '/content/drive/My Drive/Colab Notebooks/dive/Sprint19/Salt/traindata'

# %%
# !unzip '/content/drive/My Drive/Colab Notebooks/dive/Sprint19/Salt/test.zip'
# Out:
# Archive:  /content/drive/My Drive/Colab Notebooks/dive/Sprint19/Salt/test.zip
#    creating: images/
#   inflating: images/8cf16aa0f5.png
#   inflating: images/23012be6b7.png
#   inflating: images/9e46a3352e.png
#   inflating: images/8016056c46.png
#   inflating: images/a490a68472.png
#   inflating: images/cf19041b8e.png
#   inflating: images/a5c02f60cd.png
#   inflating: images/631cec82b9.png
#   inflating: images/bffa15aaa5.png
#   inflating: images/31e17c9459.png
#   inflating: images/b695427db8.png
#   inflating: images/57b062d234.png
#   inflating: images/1705ade299.png
#   inflating: images/f1a3d6352e.png
#   inflating: images/99e331e803.png
#   inflating: images/d343f6974e.png
#   inflating: images/068f7a5267.png
#   inflating: images/d4c235a41e.png
#   inflating: images/bf56f7dd40.png
#   inflating: images/6b8b1e7ad6.png
#   inflating: images/c268afb4a1.png
#   inflating: images/63ed0faeb8.png
#   inflating: images/4578fe28d8.png
#   inflating: images/8755799352.png
# ...
